# %%
import pandas as pd
Data=pd.read_excel("CFO Prediction Model vs Act_FY24.xlsx")

# %%
Data.rename(columns={'Unnamed: 1':'Shift','Unnamed: 3':"WROM_Al2O3","SO_Al_Act":"SO_Al2O3","SL_Al Act":"SL_Al2O3","SL PD":"SL_PulpDen","SL +60":"SL_60","SL +100":"SL_100","SL +300" : "SL_300","Unnamed: 14":"CFO_Al2O3","Day/ Shift":"Date",'CFO +10':"CFO_10"},inplace=True)

# %%
x={'Unnamed: 1':'Shift','Unnamed: 3':"WROM_Al2O3","SO_Al_Act":"SO_Al2O3","SL_Al Act":"SL_Al2O3","SL PD":"SL_PulpDen","SL +60":"SL_60","SL +100":"SL_100","SL +300" : "SL_300","Unnamed: 14":"CFO_Al2O3",'CFO +10':"CFO_10","Day/ Shift":"Date"}

# %%
Data.columns
# Out:
# Index(['Date', 'Shift', 'Wet ROM', 'WROM_Al2O3', 'Unnamed: 4', 'Unnamed: 5',
#        'SO_Al2O3', 'SL_Al2O3', 'SL_PulpDen', 'SL_60', 'SL_100', 'SL_300',
#        'CFO_10', 'CFO Al2O3%', 'CFO_Al2O3', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Jig Al2O3', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', '* with HCC Qnty./3 & Qlty.',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'],
#       dtype='object')

# %%
df=Data.iloc[1:,:-1][x.values()]

# %%
df.dropna(inplace=True)

# %%
df.to_csv("CFO_2024_1.csv")

# %%
Data.iloc[1:,:-1]
# Out:
#            Date Shift Wet ROM WROM_Al2O3 Unnamed: 4 Unnamed: 5  SO_Al2O3  \
# 1    2023-04-01     A    9800   4.843574   4.511224  93.138343      2.07
# 2    2023-04-01     B    5900   4.892091   4.232203   86.51113      2.25
# 3    2023-04-01     C    7200   3.738633   4.472222  80.378138      1.67
# 4    2023-04-02     A    5900   3.442515   4.032203  82.870427      2.55
# 5           NaT     B     NaN   3.565219          0          0      2.10
# ...         ...   ...     ...        ...        ...        ...       ...
# 1094        NaT     B     NaN        NaN        NaN        NaN       NaN
# 1095        NaT     C     NaN        NaN        NaN        NaN       NaN
# 1096 2023-03-31     A     NaN        NaN        NaN        NaN       NaN
# 1097        NaT     B     NaN        NaN        NaN        NaN       NaN
# 1098        NaT     C     NaN        NaN        NaN        NaN       NaN
#
#       SL_Al2O3 SL_PulpDen  SL_60  ... Unnamed: 17  Jig Al2O3  Unnamed: 19  \
# ...

# %%
Data["Date"] = pd.date_range("2023-04-01", "2024-03-31")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 Data["Date"] = pd.date_range("2023-04-01", "2024-03-31")
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
# ...

# %%
start_date = "2023-04-01"
end_date = "2024-03-31"
date_range = pd.date_range(start_date, end_date)

# Update the "Date" column with the new date range
Data["Date"] = date_range
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 6
#       3 date_range = pd.date_range(start_date, end_date)
#       5 # Update the "Date" column with the new date range
# ----> 6 Data["Date"] = date_range
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File d:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
# ...
